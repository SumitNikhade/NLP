# %% [markdown]
# <a href="https://colab.research.google.com/github/SumitNikhade/NLP/blob/main/Implementing_Inverted_Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
document1 = "The quick brown fox jumped over the lazy dog."
document2 = "The lazy dog slept in the sun."

# %%
tokens1 = document1.lower().split()
tokens2 = document2.lower().split()
print("Token1:",tokens1)
print("Token2 :",tokens2)
# Out:
# Token1: ['the', 'quick', 'brown', 'fox', 'jumped', 'over', 'the', 'lazy', 'dog.']
# Token2 : ['the', 'lazy', 'dog', 'slept', 'in', 'the', 'sun.']

# %%
terms = list(set(tokens1 + tokens2))
print("Terms :",terms)
# Out:
# Terms : ['lazy', 'brown', 'quick', 'jumped', 'fox', 'slept', 'the', 'in', 'sun.', 'over', 'dog.', 'dog']

# %%
for term in terms:
    documents = []
    if term in tokens1:
        documents.append("Document 1")
    if term in tokens2:
        documents.append("Document 2")
    inverted_index[term] = documents
print("Inverted Index Dictionary :", inverted_index)
# Out:
# Inverted Index Dictionary : {'lazy': ['Document 1', 'Document 2'], 'brown': ['Document 1'], 'quick': ['Document 1'], 'jumped': ['Document 1'], 'fox': ['Document 1'], 'slept': ['Document 2'], 'the': ['Document 1', 'Document 2'], 'in': ['Document 2'], 'sun.': ['Document 2'], 'over': ['Document 1'], 'dog.': ['Document 1'], 'dog': ['Document 2']}

# %%
for term, documents in inverted_index.items():
    print(term, "->", ", ".join(documents))
# Out:
# lazy -> Document 1, Document 2
# brown -> Document 1
# quick -> Document 1
# jumped -> Document 1
# fox -> Document 1
# slept -> Document 2
# the -> Document 1, Document 2
# in -> Document 2
# sun. -> Document 2
# over -> Document 1
# dog. -> Document 1
# dog -> Document 2
